# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("input/b",sep=" ",skiprows=1,usecols=[0])

# %%
fig = plt.figure(figsize=(12,6))
case = ["a","b","c","d","e"]
for i in range(5):
    x = case[i]
    ax = fig.add_subplot(2,3,i+1)

    with open("input/{}".format(x),mode="r") as f:
        M,T2,T3,T4 = map(int,f.readline().split())
        P = []
        I = []
        for _ in range(M):
            C = f.readline().split()
            P.append([int(C[0]),C[1:]])
            I.append(int(C[0]))

        ax.hist(I)
        print(I[:10])
    
plt.show()
# Out:
# [3, 3, 3, 3, 2]
# [5, 8, 1, 3, 1, 4, 3, 7, 3, 1]
# [157, 30, 57, 219, 92, 24, 246, 327, 42, 319]
# [1, 3, 9, 3, 2, 3, 3, 4, 2, 1]
# [1, 3, 9, 3, 2, 3, 3, 4, 2, 1]
